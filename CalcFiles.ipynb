# %%
import os

def count_npy_files(base_dir):
    """
    Crawl the base_dir for all .npy files under the structure:
      base_dir/
        <dataset_dir>/
          <sample_rate_dir>/
            <split_dir>/
              <label_dir>/
                *.npy
    and print counts per dataset, per sample rate, per split/label, plus totals.
    """
    total_files = 0
    dataset_counts = {}

    for dataset in sorted(os.listdir(base_dir)):
        dataset_path = os.path.join(base_dir, dataset)
        if not os.path.isdir(dataset_path):
            continue
        print(f"Dataset: {dataset}")
        ds_total = 0

        for sr in sorted(os.listdir(dataset_path)):
            sr_path = os.path.join(dataset_path, sr)
            if not os.path.isdir(sr_path):
                continue
            sr_total = 0

            for split in sorted(os.listdir(sr_path)):
                split_path = os.path.join(sr_path, split)
                if not os.path.isdir(split_path):
                    continue

                for label in ['filtered', 'unfiltered']:
                    label_path = os.path.join(split_path, label)
                    if not os.path.isdir(label_path):
                        continue
                    count = sum(1 for f in os.listdir(label_path) if f.endswith('.npy'))
                    print(f"  {sr}Hz/{split}/{label}: {count}")
                    sr_total += count

            print(f"  → {sr}Hz total: {sr_total}")
            ds_total += sr_total

        print(f"Dataset total: {ds_total}\n")
        dataset_counts[dataset] = ds_total
        total_files += ds_total

    print("Summary per dataset:")
    for ds, cnt in dataset_counts.items():
        print(f"  {ds}: {cnt}")
    print(f"\nOverall total .npy files: {total_files}")

if __name__ == "__main__":
    base_dir = "D:/Aliasing3/Processed_Files"  # update to your root Processed_Files path
    count_npy_files(base_dir)
# Out:
# Dataset: DS_ESC
#   1000Hz/test/filtered: 197
#   1000Hz/test/unfiltered: 197
#   1000Hz/train/filtered: 1503
#   1000Hz/train/unfiltered: 1519
#   1000Hz/validation/filtered: 191
#   1000Hz/validation/unfiltered: 175
#   → 1000Hz total: 3782
#   16000Hz/test/filtered: 198
#   16000Hz/test/unfiltered: 174
#   16000Hz/train/filtered: 1539
#   16000Hz/train/unfiltered: 1516
#   16000Hz/validation/filtered: 154
#   16000Hz/validation/unfiltered: 201
#   → 16000Hz total: 3782
#   2000Hz/test/filtered: 199
#   2000Hz/test/unfiltered: 177
#   2000Hz/train/filtered: 1493
#   2000Hz/train/unfiltered: 1506
#   2000Hz/validation/filtered: 199
#   2000Hz/validation/unfiltered: 208
#   → 2000Hz total: 3782
#   22000Hz/test/filtered: 185
#   22000Hz/test/unfiltered: 195
#   22000Hz/train/filtered: 1526
#   22000Hz/train/unfiltered: 1509
#   22000Hz/validation/filtered: 180
#   22000Hz/validation/unfiltered: 187
#   → 22000Hz total: 3782
#   4000Hz/test/filtered: 195
#   4000Hz/test/unfiltered: 188
#   4000Hz/train/filtered: 1520
#   4000Hz/train/unfiltered: 1512
#   4000Hz/validation/filtered: 176
#   4000Hz/validation/unfiltered: 191
#   → 4000Hz total: 3782
#   8000Hz/test/filtered: 166
#   8000Hz/test/unfiltered: 199
#   8000Hz/train/filtered: 1509
#   8000Hz/train/unfiltered: 1501
#   8000Hz/validation/filtered: 216
#   8000Hz/validation/unfiltered: 191
#   → 8000Hz total: 3782
#   → modelsHz total: 0
# Dataset total: 22692
#
# Dataset: DS_ESC_MFCC
#   1000Hz/test/filtered: 197
#   1000Hz/test/unfiltered: 197
#   1000Hz/train/filtered: 1503
#   1000Hz/train/unfiltered: 1519
#   1000Hz/validation/filtered: 191
#   1000Hz/validation/unfiltered: 175
#   → 1000Hz total: 3782
#   16000Hz/test/filtered: 198
#   16000Hz/test/unfiltered: 174
#   16000Hz/train/filtered: 1539
#   16000Hz/train/unfiltered: 1516
#   16000Hz/validation/filtered: 154
#   16000Hz/validation/unfiltered: 201
#   → 16000Hz total: 3782
#   2000Hz/test/filtered: 199
#   2000Hz/test/unfiltered: 177
#   2000Hz/train/filtered: 1493
#   2000Hz/train/unfiltered: 1506
#   2000Hz/validation/filtered: 199
#   2000Hz/validation/unfiltered: 208
#   → 2000Hz total: 3782
#   22000Hz/test/filtered: 185
#   22000Hz/test/unfiltered: 195
#   22000Hz/train/filtered: 1526
#   22000Hz/train/unfiltered: 1509
#   22000Hz/validation/filtered: 180
#   22000Hz/validation/unfiltered: 187
#   → 22000Hz total: 3782
#   4000Hz/test/filtered: 195
#   4000Hz/test/unfiltered: 188
#   4000Hz/train/filtered: 1520
#   4000Hz/train/unfiltered: 1512
#   4000Hz/validation/filtered: 176
#   4000Hz/validation/unfiltered: 191
#   → 4000Hz total: 3782
#   8000Hz/test/filtered: 166
#   8000Hz/test/unfiltered: 199
#   8000Hz/train/filtered: 1509
#   8000Hz/train/unfiltered: 1501
#   8000Hz/validation/filtered: 216
#   8000Hz/validation/unfiltered: 191
#   → 8000Hz total: 3782
#   → modelsHz total: 0
# Dataset total: 22692
#
# Dataset: DS_U8K
#   1000Hz/test/filtered: 631
#   1000Hz/test/unfiltered: 637
#   1000Hz/train/filtered: 5040
#   1000Hz/train/unfiltered: 5056
#   1000Hz/validation/filtered: 618
#   1000Hz/validation/unfiltered: 596
#   → 1000Hz total: 12578
#   16000Hz/test/filtered: 603
#   16000Hz/test/unfiltered: 602
#   16000Hz/train/filtered: 5077
#   16000Hz/train/unfiltered: 5030
#   16000Hz/validation/filtered: 609
#   16000Hz/validation/unfiltered: 657
#   → 16000Hz total: 12578
#   2000Hz/test/filtered: 632
#   2000Hz/test/unfiltered: 628
#   2000Hz/train/filtered: 5025
#   2000Hz/train/unfiltered: 5024
#   2000Hz/validation/filtered: 632
#   2000Hz/validation/unfiltered: 637
#   → 2000Hz total: 12578
#   22000Hz/test/filtered: 641
#   22000Hz/test/unfiltered: 645
#   22000Hz/train/filtered: 4973
#   22000Hz/train/unfiltered: 5067
#   22000Hz/validation/filtered: 675
#   22000Hz/validation/unfiltered: 577
#   → 22000Hz total: 12578
#   4000Hz/test/filtered: 611
#   4000Hz/test/unfiltered: 628
#   4000Hz/train/filtered: 5052
#   4000Hz/train/unfiltered: 5029
#   4000Hz/validation/filtered: 626
#   4000Hz/validation/unfiltered: 632
#   → 4000Hz total: 12578
#   8000Hz/test/filtered: 646
#   8000Hz/test/unfiltered: 644
#   8000Hz/train/filtered: 5026
#   8000Hz/train/unfiltered: 4975
#   8000Hz/validation/filtered: 617
#   8000Hz/validation/unfiltered: 670
#   → 8000Hz total: 12578
#   → modelsHz total: 0
# Dataset total: 75468
#
# Dataset: DS_U8K_MFCC
#   1000Hz/test/filtered: 631
#   1000Hz/test/unfiltered: 637
#   1000Hz/train/filtered: 5040
#   1000Hz/train/unfiltered: 5056
#   1000Hz/validation/filtered: 618
#   1000Hz/validation/unfiltered: 596
#   → 1000Hz total: 12578
#   16000Hz/test/filtered: 603
#   16000Hz/test/unfiltered: 602
#   16000Hz/train/filtered: 5077
#   16000Hz/train/unfiltered: 5030
#   16000Hz/validation/filtered: 609
#   16000Hz/validation/unfiltered: 657
#   → 16000Hz total: 12578
#   2000Hz/test/filtered: 632
#   2000Hz/test/unfiltered: 628
#   2000Hz/train/filtered: 5025
#   2000Hz/train/unfiltered: 5024
#   2000Hz/validation/filtered: 632
#   2000Hz/validation/unfiltered: 637
#   → 2000Hz total: 12578
#   22000Hz/test/filtered: 641
#   22000Hz/test/unfiltered: 645
#   22000Hz/train/filtered: 4973
#   22000Hz/train/unfiltered: 5067
#   22000Hz/validation/filtered: 675
#   22000Hz/validation/unfiltered: 577
#   → 22000Hz total: 12578
#   4000Hz/test/filtered: 611
#   4000Hz/test/unfiltered: 628
#   4000Hz/train/filtered: 5052
#   4000Hz/train/unfiltered: 5029
#   4000Hz/validation/filtered: 626
#   4000Hz/validation/unfiltered: 632
#   → 4000Hz total: 12578
#   8000Hz/test/filtered: 646
#   8000Hz/test/unfiltered: 644
#   8000Hz/train/filtered: 5026
#   8000Hz/train/unfiltered: 4975
#   8000Hz/validation/filtered: 617
#   8000Hz/validation/unfiltered: 670
#   → 8000Hz total: 12578
#   → modelsHz total: 0
# Dataset total: 75468
#
# Dataset: DS_ZEN
#   1000Hz/test/filtered: 549
#   1000Hz/test/unfiltered: 539
#   1000Hz/train/filtered: 4457
#   1000Hz/train/unfiltered: 4485
#   1000Hz/validation/filtered: 555
#   1000Hz/validation/unfiltered: 537
#   → 1000Hz total: 11122
#   16000Hz/test/filtered: 542
#   16000Hz/test/unfiltered: 544
#   16000Hz/train/filtered: 4439
#   16000Hz/train/unfiltered: 4426
#   16000Hz/validation/filtered: 580
#   16000Hz/validation/unfiltered: 591
#   → 16000Hz total: 11122
#   2000Hz/test/filtered: 560
#   2000Hz/test/unfiltered: 599
#   2000Hz/train/filtered: 4437
#   2000Hz/train/unfiltered: 4416
#   2000Hz/validation/filtered: 564
#   2000Hz/validation/unfiltered: 546
#   → 2000Hz total: 11122
#   22000Hz/test/filtered: 517
#   22000Hz/test/unfiltered: 570
#   22000Hz/train/filtered: 4522
#   22000Hz/train/unfiltered: 4436
#   22000Hz/validation/filtered: 522
#   22000Hz/validation/unfiltered: 555
#   → 22000Hz total: 11122
#   4000Hz/test/filtered: 552
#   4000Hz/test/unfiltered: 575
#   4000Hz/train/filtered: 4471
#   4000Hz/train/unfiltered: 4444
#   4000Hz/validation/filtered: 538
#   4000Hz/validation/unfiltered: 542
#   → 4000Hz total: 11122
#   8000Hz/test/filtered: 566
#   8000Hz/test/unfiltered: 561
#   8000Hz/train/filtered: 4415
#   8000Hz/train/unfiltered: 4437
#   8000Hz/validation/filtered: 580
#   8000Hz/validation/unfiltered: 563
#   → 8000Hz total: 11122
#   → modelsHz total: 0
# Dataset total: 66732
#
# Dataset: DS_ZEN_MFCC
#   1000Hz/test/filtered: 2740
#   1000Hz/test/unfiltered: 2626
#   1000Hz/train/filtered: 21558
#   1000Hz/train/unfiltered: 21640
#   1000Hz/validation/filtered: 2727
#   1000Hz/validation/unfiltered: 2759
#   → 1000Hz total: 54050
#   16000Hz/test/filtered: 2697
#   16000Hz/test/unfiltered: 2698
#   16000Hz/train/filtered: 21592
#   16000Hz/train/unfiltered: 21683
#   16000Hz/validation/filtered: 2739
#   16000Hz/validation/unfiltered: 2643
#   → 16000Hz total: 54052
#   2000Hz/test/filtered: 2665
#   2000Hz/test/unfiltered: 2710
#   2000Hz/train/filtered: 21585
#   2000Hz/train/unfiltered: 21624
#   2000Hz/validation/filtered: 2773
#   2000Hz/validation/unfiltered: 2691
#   → 2000Hz total: 54048
#   22000Hz/test/filtered: 2679
#   22000Hz/test/unfiltered: 2720
#   22000Hz/train/filtered: 21629
#   22000Hz/train/unfiltered: 21643
#   22000Hz/validation/filtered: 2716
#   22000Hz/validation/unfiltered: 2662
#   → 22000Hz total: 54049
#   4000Hz/test/filtered: 2694
#   4000Hz/test/unfiltered: 2780
#   4000Hz/train/filtered: 21585
#   4000Hz/train/unfiltered: 21586
#   4000Hz/validation/filtered: 2746
#   4000Hz/validation/unfiltered: 2660
#   → 4000Hz total: 54051
#   8000Hz/test/filtered: 2729
#   8000Hz/test/unfiltered: 2692
#   8000Hz/train/filtered: 21607
#   8000Hz/train/unfiltered: 21707
#   8000Hz/validation/filtered: 2687
#   8000Hz/validation/unfiltered: 2626
#   → 8000Hz total: 54048
#   → modelsHz total: 0
# Dataset total: 324298
#
# Summary per dataset:
#   DS_ESC: 22692
#   DS_ESC_MFCC: 22692
#   DS_U8K: 75468
#   DS_U8K_MFCC: 75468
#   DS_ZEN: 66732
#   DS_ZEN_MFCC: 324298
#
# Overall total .npy files: 587350

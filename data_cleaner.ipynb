# %%
import pandas as pd
import glob

import pandas as pd
import re
import os

def parse_filename(file_name):
    """
    Extracts dataset type and sample rate from the file name.
    Expected format: lstm_grid_DS_<DATASET>_<SAMPLERATE>_<DATE>.csv
    """
    file_name_split = file_name.split("_")
    ds = file_name_split[3]
    ds_type = "MFCC" if "MFCC" in file_name else "STFT"
    sr = int(file_name_split[-3])

    return ds, sr, ds_type

def combine_top_models(file_list):
    """
    Combines the highest F1 score row from each CSV file with metadata.

    Parameters:
        file_list (list of str): List of file paths.

    Returns:
        pd.DataFrame: Combined DataFrame with best models and metadata.
    """
    top_models = []

    for file_name in file_list:
        df = pd.read_csv(file_name)
        dataset, sample_rate, ds_type = parse_filename(file_name)
        top_row = df.loc[df['f1_score'].idxmax()].copy()
        top_row['dataset'] = dataset
        top_row['file_type'] = ds_type
        top_row['sample_rate'] = sample_rate
        top_row['source_file'] = file_name
        top_models.append(top_row)

    return pd.DataFrame(top_models)

def get_csv_filenames_in_current_dir(pattern="lstm_grid_DS_*.csv"):
    """
    Returns a list of CSV file names in the current directory matching the pattern.

    Parameters:
        pattern (str): Glob pattern to match filenames. Default targets 'lstm_grid_DS_*.csv'.

    Returns:
        list of str: List of matching filenames.
    """
    current_dir = "."
    search_pattern = os.path.join(current_dir, pattern)
    return glob.glob(search_pattern)

# Example usage
if __name__ == "__main__":
    file_paths = get_csv_filenames_in_current_dir()
    best_models = combine_top_models(file_paths)
    print(best_models)
    # Optionally save:
    best_models.to_csv("top_models_summary.csv", index=False)
# Out:
#    sample_rate  hidden_dim  fc_dim  f1_score dataset file_type  \
# 0         1000        64.0    32.0  0.342908     ESC      STFT
# 1        16000        64.0    64.0  0.572695     ESC      STFT
# 0         2000        64.0    32.0  0.338211     ESC      STFT
# 0        22000        64.0    32.0  0.614090     ESC      STFT
# 1         4000        64.0    64.0  0.598489     ESC      STFT
# 2         8000       128.0    32.0  0.521173     ESC      STFT
# 1         1000        64.0    64.0  0.590669     ESC      MFCC
# 1        16000        64.0    64.0  0.630564     ESC      MFCC
# 2         2000       128.0    32.0  0.642691     ESC      MFCC
# 3        22000       128.0    64.0  0.612432     ESC      MFCC
# 3         4000       128.0    64.0  0.673003     ESC      MFCC
# 1         8000        64.0    64.0  0.628266     ESC      MFCC
# 3         1000       128.0    64.0  0.339196     U8K      STFT
# 1        16000        64.0    64.0  0.627251     U8K      STFT
# 2         2000       128.0    32.0  0.557720     U8K      STFT
# 3        22000       128.0    64.0  0.604626     U8K      STFT
# 1         4000        64.0    64.0  0.627138     U8K      STFT
# 1         8000        64.0    64.0  0.629367     U8K      STFT
# 3         1000       128.0    64.0  0.720141     U8K      MFCC
# 3        16000       128.0    64.0  0.725002     U8K      MFCC
# 2         2000       128.0    32.0  0.730899     U8K      MFCC
# 2        22000       128.0    32.0  0.713569     U8K      MFCC
# 3         4000       128.0    64.0  0.788500     U8K      MFCC
# 2         8000       128.0    32.0  0.730497     U8K      MFCC
# 3         1000       128.0    64.0  0.743184     ZEN      STFT
# 1        16000        64.0    64.0  0.335414     ZEN      STFT
# 1         2000        64.0    64.0  0.757259     ZEN      STFT
# 3        22000       128.0    64.0  0.329167     ZEN      STFT
# 3         4000       128.0    64.0  0.717290     ZEN      STFT
# 2         8000       128.0    32.0  0.336622     ZEN      STFT
# 2         1000       128.0    32.0  0.689581     ZEN      MFCC
# 3        16000       128.0    64.0  0.695066     ZEN      MFCC
# 3         2000       128.0    64.0  0.701090     ZEN      MFCC
# 3        22000       128.0    64.0  0.686213     ZEN      MFCC
# 2         4000       128.0    32.0  0.726043     ZEN      MFCC
# 2         8000       128.0    32.0  0.733612     ZEN      MFCC
#
#                                          source_file
# 0        .\lstm_grid_DS_ESC_1000_20250718_232609.csv
# 1       .\lstm_grid_DS_ESC_16000_20250718_234937.csv
# 0        .\lstm_grid_DS_ESC_2000_20250718_233142.csv
# 0       .\lstm_grid_DS_ESC_22000_20250718_235553.csv
# 1        .\lstm_grid_DS_ESC_4000_20250718_233722.csv
# 2        .\lstm_grid_DS_ESC_8000_20250718_234303.csv
# 1   .\lstm_grid_DS_ESC_MFCC_1000_20250720_203335.csv
# 1  .\lstm_grid_DS_ESC_MFCC_16000_20250720_204405.csv
# 2   .\lstm_grid_DS_ESC_MFCC_2000_20250720_203624.csv
# 3  .\lstm_grid_DS_ESC_MFCC_22000_20250720_204640.csv
# 3   .\lstm_grid_DS_ESC_MFCC_4000_20250720_203854.csv
# 1   .\lstm_grid_DS_ESC_MFCC_8000_20250720_204133.csv
# 3        .\lstm_grid_DS_U8K_1000_20250720_185255.csv
# 1       .\lstm_grid_DS_U8K_16000_20250718_225930.csv
# 2        .\lstm_grid_DS_U8K_2000_20250720_191129.csv
# 3       .\lstm_grid_DS_U8K_22000_20250718_232031.csv
# 1        .\lstm_grid_DS_U8K_4000_20250718_221937.csv
# 1        .\lstm_grid_DS_U8K_8000_20250718_223804.csv
# 3   .\lstm_grid_DS_U8K_MFCC_1000_20250720_194820.csv
# 3  .\lstm_grid_DS_U8K_MFCC_16000_20250720_202300.csv
# 2   .\lstm_grid_DS_U8K_MFCC_2000_20250720_195809.csv
# 2  .\lstm_grid_DS_U8K_MFCC_22000_20250720_203047.csv
# 3   .\lstm_grid_DS_U8K_MFCC_4000_20250720_200612.csv
# 2   .\lstm_grid_DS_U8K_MFCC_8000_20250720_201430.csv
# 3        .\lstm_grid_DS_ZEN_1000_20250726_130348.csv
# 1       .\lstm_grid_DS_ZEN_16000_20250726_134954.csv
# 1        .\lstm_grid_DS_ZEN_2000_20250726_131402.csv
# 3       .\lstm_grid_DS_ZEN_22000_20250726_140420.csv
# 3        .\lstm_grid_DS_ZEN_4000_20250726_132434.csv
# 2        .\lstm_grid_DS_ZEN_8000_20250726_133527.csv
# 2   .\lstm_grid_DS_ZEN_MFCC_1000_20250720_213036.csv
# 3  .\lstm_grid_DS_ZEN_MFCC_16000_20250721_004346.csv
# 3   .\lstm_grid_DS_ZEN_MFCC_2000_20250720_221130.csv
# 3  .\lstm_grid_DS_ZEN_MFCC_22000_20250721_012844.csv
# 2   .\lstm_grid_DS_ZEN_MFCC_4000_20250720_230513.csv
# 2   .\lstm_grid_DS_ZEN_MFCC_8000_20250721_000454.csv
